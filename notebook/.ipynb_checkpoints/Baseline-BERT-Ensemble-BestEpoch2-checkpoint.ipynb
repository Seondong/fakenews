# %% [markdown]
# * https://www.kaggle.com/c/fake-news-pair-classification-challenge/data
# * https://github.com/fxsjy/jieba
#
# BERT
# * https://colab.research.google.com/github/tensorflow/tpu/blob/master/tools/colab/bert_finetuning_with_cloud_tpus.ipynb#scrollTo=Hcpfl4N2EdOk
# * https://github.com/google-research/bert/blob/master/multilingual.md
#
# Gluon-bert
# * https://gluon-nlp.mxnet.io/examples/sentence_embedding/bert.html
#
# Embedding options
# * https://github.com/Embedding/Chinese-Word-Vectors (Embedding 1)
# * https://github.com/facebookresearch/fastText/blob/master/docs/crawl-vectors.md (Embedding 2)
#
# Performance
# * Using Embedding 1: Performance 0.70640
# * Using Embedding 2: Performance 0.68641
# * Using BERT: Performance 0.849
# * Using BERT_WEIGHTED: Performance 0.85526
# * Using BERT_WEIGHTED+SameTID-Agreed: 0.85479
#     * Example: df_test[df_test.pred_label != df_test.pred_label2]인 아이들 다 agreed
# * Using BERT_WEIGHTED_train100: Performance 0.85634
# * Using BERT_ensemble_3models (cn, multi, uncased24): Performance 0.85619
# * Using BERT_ensemble_4models_weighted (cn, cnen, multi, uncased24): Performance 0.86283
#
# 내일 submission: train / validation을 통해 epoch 최고값 잡고, 여러모델 최종값 merge

# %%
cd /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/bert_repo
# Out:
# /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/bert_repo

# %%
import modeling
import optimization
import run_classifier
import tokenization

# %%
cd /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook
# Out:
# /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook

# %%
import datetime
import glob
import pandas as pd
import numpy as np
import os
import pickle

# %%
import tensorflow as tf
import keras

os.environ["CUDA_VISIBLE_DEVICES"] = "3,4,5"

from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config))

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1858805157057303356
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13335760784335517778
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14657818925059034647
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10764677940
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17446539536940473458
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:0b:00.0, compute capability: 7.0"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 10764677940
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 8793040830281162775
# physical_device_desc: "device: 1, name: Tesla V100-SXM2-16GB, pci bus id: 0000:85:00.0, compute capability: 7.0"
# , name: "/device:GPU:2"
# device_type: "GPU"
# memory_limit: 12490004890
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 632573764175683220
# physical_device_desc: "device: 2, name: Tesla V100-SXM2-16GB, pci bus id: 0000:86:00.0, compute capability: 7.0"
# ]

# %%
def input_fn_builder(features, seq_length, is_training, drop_remainder):
    all_input_ids = []
    all_input_mask = []
    all_segment_ids = []
    all_label_ids = []

    for feature in features:
        all_input_ids.append(feature.input_ids)
        all_input_mask.append(feature.input_mask)
        all_segment_ids.append(feature.segment_ids)
        all_label_ids.append(feature.label_id)

    def input_fn(params):

        batch_size = 128

        num_examples = len(features)

        # This is for demo purposes and does NOT scale to large data sets. We do
        # not use Dataset.from_generator() because that uses tf.py_func which is
        # not TPU compatible. The right way to load data is with TFRecordReader.
        d = tf.data.Dataset.from_tensor_slices({
            "input_ids":
                tf.constant(
                    all_input_ids, shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "input_mask":
                tf.constant(
                    all_input_mask,
                    shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "segment_ids":
                tf.constant(
                    all_segment_ids,
                    shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "label_ids":
                tf.constant(all_label_ids, shape=[num_examples], dtype=tf.int32),
        })

        if is_training:
            d = d.repeat()
            d = d.shuffle(buffer_size=100)

        d = d.batch(batch_size=batch_size, drop_remainder=drop_remainder)
        return d

    return input_fn

# %%
BERT_MODEL_LIST = ['chinese_L-12_H-768_A-12', 'multi_cased_L-12_H-768_A-12', 'uncased_L-24_H-1024_A-16']
['/home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_'+model for model in BERT_MODEL_LIST]
# Out:
# ['/home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_chinese_L-12_H-768_A-12',
#  '/home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_multi_cased_L-12_H-768_A-12',
#  '/home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_uncased_L-24_H-1024_A-16']

# %%
# Available pretrained model checkpoints:
#   uncased_L-12_H-768_A-12: uncased BERT base model
#   uncased_L-24_H-1024_A-16: uncased BERT large model
#   cased_L-12_H-768_A-12: cased BERT large model

exp_marker = 'crude-ensemble-geomean'
TASK_DATA_DIR = '../data/FakeNews_BERT/FakeNews_BERT/'


# BERT_MODEL_LIST = ['chinese_L-12_H-768_A-12', 'multi_cased_L-12_H-768_A-12', 'uncased_L-24_H-1024_A-16']
BERT_MODEL_LIST = ['chinese_L-12_H-768_A-12']

for BERT_MODEL in BERT_MODEL_LIST:
    
    train_path = '../data/train.csv'
    df_train = pd.read_csv(train_path)

    df_train['title1_zh'] = df_train.title1_zh.apply(lambda x: str(x).replace('\n', ','))
    df_train['title1_zh'] = df_train.title1_zh.apply(lambda x: str(x).replace('\t', ','))
    df_train['title2_zh'] = df_train.title2_zh.apply(lambda x: str(x).replace('\n', ','))
    df_train['title2_zh'] = df_train.title2_zh.apply(lambda x: str(x).replace('\t', ','))

    idxs = list(df_train.index)
    np.random.shuffle(idxs)
    val_num = len(idxs) // 5 
    train_idxs = idxs[:-val_num] 
    val_idxs = idxs[-val_num:]

    df_tra = df_train.loc[train_idxs, :][['title1_zh', 'title2_zh', 'label']]
    df_val = df_train.loc[val_idxs, :][['title1_zh', 'title2_zh', 'label']]

    df_tra.to_csv('../data/FakeNews_BERT/FakeNews_BERT/train_80_2.tsv', sep='\t',header=True, index=False)
    df_val.to_csv('../data/FakeNews_BERT/FakeNews_BERT/dev_20_2.tsv', sep='\t',header=True, index=False)
    
    
    BERT_PRETRAINED_DIR = '../data/' + BERT_MODEL
    OUTPUT_DIR = '/home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_'+BERT_MODEL

    print('***** BERT pretrained directory: {} *****'.format(BERT_PRETRAINED_DIR))
    print('***** Model output directory: {} *****'.format(OUTPUT_DIR))
    
    if BERT_MODEL == 'uncased_L-24_H-1024_A-16':
        TRAIN_BATCH_SIZE = 12
        EVAL_BATCH_SIZE = 12
        TEST_BATCH_SIZE = 12
        LEARNING_RATE = 2e-5
        NUM_TRAIN_EPOCHS = 3.0
        WARMUP_PROPORTION = 0.1
        MAX_SEQ_LENGTH = 43  # According to our dataset, length of 43 can cover 99.5% of the titles.
        TASK = 'FakeEN' 
    else:
        # Model Hyper Parameters
        TRAIN_BATCH_SIZE = 128 # 32
        EVAL_BATCH_SIZE = 128  # 8    
        TEST_BATCH_SIZE = 128  # 8    
        LEARNING_RATE = 2e-5
        NUM_TRAIN_EPOCHS = 10.0
        WARMUP_PROPORTION = 0.1
        MAX_SEQ_LENGTH = 43  # According to our dataset, length of 43 can cover 99.5% of the titles.
        TASK = 'Fake'
        
    # Model configs
    SAVE_CHECKPOINTS_STEPS = 1000
    ITERATIONS_PER_LOOP = 1000
    NUM_TPU_CORES = 8
    VOCAB_FILE = os.path.join(BERT_PRETRAINED_DIR, 'vocab.txt')
    CONFIG_FILE = os.path.join(BERT_PRETRAINED_DIR, 'bert_config.json')
    INIT_CHECKPOINT = os.path.join(BERT_PRETRAINED_DIR, 'bert_model.ckpt')
    DO_LOWER_CASE = BERT_MODEL.startswith('uncased')

    processors = {
      "cola": run_classifier.ColaProcessor,
      "mnli": run_classifier.MnliProcessor,
      "mrpc": run_classifier.MrpcProcessor,
      "fake": run_classifier.FakeProcessor,
      "fakeen": run_classifier.FakeENProcessor,  
    }
    processor = processors[TASK.lower()]()
    label_list = processor.get_labels()
    
    tokenizer = tokenization.FullTokenizer(vocab_file=VOCAB_FILE, do_lower_case=DO_LOWER_CASE)
    tpu_cluster_resolver = None
    
#     run_config = tf.estimator.RunConfig(
#         model_dir=OUTPUT_DIR,
#         save_checkpoints_steps=SAVE_CHECKPOINTS_STEPS,
#     )

    run_config = tf.contrib.tpu.RunConfig(
        cluster=tpu_cluster_resolver,
        model_dir=OUTPUT_DIR,
        save_checkpoints_steps=SAVE_CHECKPOINTS_STEPS,
        tpu_config=tf.contrib.tpu.TPUConfig(
            iterations_per_loop=ITERATIONS_PER_LOOP,
            num_shards=NUM_TPU_CORES,
            per_host_input_for_training=tf.contrib.tpu.InputPipelineConfig.PER_HOST_V2))
    

    train_examples = processor.get_train_examples(TASK_DATA_DIR)
    eval_examples = processor.get_dev_examples(TASK_DATA_DIR)

    num_train_steps = int(
        len(train_examples) / TRAIN_BATCH_SIZE * NUM_TRAIN_EPOCHS)
    num_warmup_steps = int(num_train_steps * WARMUP_PROPORTION)

    model_fn = run_classifier.model_fn_builder(
        bert_config=modeling.BertConfig.from_json_file(CONFIG_FILE),
        num_labels=len(label_list),
        init_checkpoint=INIT_CHECKPOINT,
        learning_rate=LEARNING_RATE,
        num_train_steps=num_train_steps,
        num_warmup_steps=num_warmup_steps,
        use_tpu = False,
        use_one_hot_embeddings=True)
    
    estimator = tf.contrib.tpu.TPUEstimator(
        use_tpu=False,
        model_fn=model_fn,
        config=run_config,
        train_batch_size=TRAIN_BATCH_SIZE,
        eval_batch_size=EVAL_BATCH_SIZE)
    
    
    # Train the model.
    print('Feature generating with train data')
    
    train_features = run_classifier.convert_examples_to_features(
        train_examples, label_list, MAX_SEQ_LENGTH, tokenizer)
    
    eval_features = run_classifier.convert_examples_to_features(
        eval_examples, label_list, MAX_SEQ_LENGTH, tokenizer)
    
    
    print('***** Started training at {} *****'.format(datetime.datetime.now()))
    print('  Num examples = {}'.format(len(train_examples)))
    print('  Batch size = {}'.format(TRAIN_BATCH_SIZE))
    tf.logging.info("  Num steps = %d", num_train_steps)
    
    train_input_fn = run_classifier.input_fn_builder(
        features=train_features,
        seq_length=MAX_SEQ_LENGTH,
        is_training=True,
        drop_remainder=False)
    
    
    eval_input_fn = input_fn_builder(
        features=eval_features,
        seq_length=MAX_SEQ_LENGTH,
        is_training=False,
        drop_remainder=False)
    
    
    train_spec = tf.estimator.TrainSpec(input_fn=train_input_fn, max_steps=num_train_steps)
    eval_spec = tf.estimator.EvalSpec(input_fn=eval_input_fn)
    
    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
    
#     estimator.train(input_fn=train_input_fn, max_steps=num_train_steps)
#     print('***** Finished training at {} *****'.format(datetime.datetime.now()))

    
    
    # Test the model.
    test_examples = processor.get_test_examples(TASK_DATA_DIR)
    test_features = run_classifier.convert_examples_to_features(
        test_examples, label_list, MAX_SEQ_LENGTH, tokenizer)

    # Eval will be slightly WRONG on the TPU because it will truncate
    # the last batch.
    test_input_fn = input_fn_builder(          # run_classifier.
        features=test_features,
        seq_length=MAX_SEQ_LENGTH,
        is_training=False,
        drop_remainder=False)

    result = estimator.predict(input_fn=test_input_fn)

    raw_result_list = []
    result_list = []
    for rr in result:
        raw_result_list.append(rr)
        result_list.append(np.argmax(rr))

        
    test_path = '../data/test.csv'
    submission_path = '../data/sample_submission_BERTopt2_'+BERT_MODEL+'.csv'
    submission_all_path = '../data/sample_submission_BERTopt2_'+BERT_MODEL+'_ALL.csv'
    result_raw_path = '../data/sample_submission_sd_BERTopt2_'+BERT_MODEL+'_RESULT_SOFTMAX.p'
    df_test = pd.read_csv(test_path)
    df_test['pred_label'] = result_list
    idx_label = {0:'unrelated', 1:'agreed', 2:'disagreed'}
    df_test['pred_label'] = df_test['pred_label'].apply(lambda x: idx_label[x])

    df_test[['id', 'pred_label']].rename(columns={'id':'Id','pred_label':'Category'}).to_csv(submission_path, index=False)
    df_test.to_csv(submission_all_path, index=False)

    pickle.dump(raw_result_list, open(result_raw_path, 'wb'))
# Out:
# ***** BERT pretrained directory: ../data/chinese_L-12_H-768_A-12 *****
# ***** Model output directory: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12 *****
# WARNING:tensorflow:Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f7199bc89d8>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': '/home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7199146518>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=1000, num_shards=8, num_cores_per_replica=None, per_host_input_for_training=3, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# WARNING:tensorflow:eval_on_tpu ignored because use_tpu is False.
# Feature generating with train data
# INFO:tensorflow:Writing example 0 of 256442
# INFO:tensorflow:Writing example 10000 of 256442
# INFO:tensorflow:Writing example 20000 of 256442
# INFO:tensorflow:Writing example 30000 of 256442
# INFO:tensorflow:Writing example 40000 of 256442
# INFO:tensorflow:Writing example 50000 of 256442
# INFO:tensorflow:Writing example 60000 of 256442
# INFO:tensorflow:Writing example 70000 of 256442
# INFO:tensorflow:Writing example 80000 of 256442
# INFO:tensorflow:Writing example 90000 of 256442
# INFO:tensorflow:Writing example 100000 of 256442
# INFO:tensorflow:Writing example 110000 of 256442
# INFO:tensorflow:Writing example 120000 of 256442
# INFO:tensorflow:Writing example 130000 of 256442
# INFO:tensorflow:Writing example 140000 of 256442
# INFO:tensorflow:Writing example 150000 of 256442
# INFO:tensorflow:Writing example 160000 of 256442
# INFO:tensorflow:Writing example 170000 of 256442
# INFO:tensorflow:Writing example 180000 of 256442
# INFO:tensorflow:Writing example 190000 of 256442
# INFO:tensorflow:Writing example 200000 of 256442
# INFO:tensorflow:Writing example 210000 of 256442
# INFO:tensorflow:Writing example 220000 of 256442
# INFO:tensorflow:Writing example 230000 of 256442
# INFO:tensorflow:Writing example 240000 of 256442
# INFO:tensorflow:Writing example 250000 of 256442
# INFO:tensorflow:Writing example 0 of 64110
# INFO:tensorflow:Writing example 10000 of 64110
# INFO:tensorflow:Writing example 20000 of 64110
# INFO:tensorflow:Writing example 30000 of 64110
# INFO:tensorflow:Writing example 40000 of 64110
# INFO:tensorflow:Writing example 50000 of 64110
# INFO:tensorflow:Writing example 60000 of 64110
# ***** Started training at 2018-12-10 02:54:30.447483 *****
#   Num examples = 256442
#   Batch size = 128
# INFO:tensorflow:  Num steps = 20034
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.14376
# INFO:tensorflow:examples/sec: 146.401
# INFO:tensorflow:global_step/sec: 1.22988
# INFO:tensorflow:examples/sec: 157.425
# INFO:tensorflow:global_step/sec: 1.20432
# INFO:tensorflow:examples/sec: 154.152
# INFO:tensorflow:global_step/sec: 1.20694
# INFO:tensorflow:examples/sec: 154.488
# INFO:tensorflow:global_step/sec: 1.22745
# INFO:tensorflow:examples/sec: 157.114
# INFO:tensorflow:global_step/sec: 1.22885
# INFO:tensorflow:examples/sec: 157.293
# INFO:tensorflow:global_step/sec: 1.22133
# INFO:tensorflow:examples/sec: 156.331
# INFO:tensorflow:global_step/sec: 1.18831
# INFO:tensorflow:examples/sec: 152.104
# INFO:tensorflow:global_step/sec: 1.2227
# INFO:tensorflow:examples/sec: 156.505
# INFO:tensorflow:Saving checkpoints for 1000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-11:10:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-11:11:03
# INFO:tensorflow:Saving dict for global step 1000: eval_accuracy = 0.847344, eval_loss = 0.0241835, global_step = 1000, loss = 0.0241835
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-1000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.788777
# INFO:tensorflow:examples/sec: 100.963
# INFO:tensorflow:global_step/sec: 1.19446
# INFO:tensorflow:examples/sec: 152.891
# INFO:tensorflow:global_step/sec: 1.22614
# INFO:tensorflow:examples/sec: 156.946
# INFO:tensorflow:global_step/sec: 1.49668
# INFO:tensorflow:examples/sec: 191.575
# INFO:tensorflow:global_step/sec: 1.3986
# INFO:tensorflow:examples/sec: 179.02
# INFO:tensorflow:global_step/sec: 1.23595
# INFO:tensorflow:examples/sec: 158.201
# INFO:tensorflow:global_step/sec: 1.20701
# INFO:tensorflow:examples/sec: 154.498
# INFO:tensorflow:global_step/sec: 1.26383
# INFO:tensorflow:examples/sec: 161.771
# INFO:tensorflow:global_step/sec: 1.20971
# INFO:tensorflow:examples/sec: 154.843
# INFO:tensorflow:global_step/sec: 1.22506
# INFO:tensorflow:examples/sec: 156.808
# INFO:tensorflow:Saving checkpoints for 2000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-11:24:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-11:25:01
# INFO:tensorflow:Saving dict for global step 2000: eval_accuracy = 0.870703, eval_loss = 0.0219045, global_step = 2000, loss = 0.0219045
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-2000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.787809
# INFO:tensorflow:examples/sec: 100.84
# INFO:tensorflow:global_step/sec: 1.25262
# INFO:tensorflow:examples/sec: 160.335
# INFO:tensorflow:global_step/sec: 1.2476
# INFO:tensorflow:examples/sec: 159.693
# INFO:tensorflow:global_step/sec: 1.19544
# INFO:tensorflow:examples/sec: 153.017
# INFO:tensorflow:global_step/sec: 1.26752
# INFO:tensorflow:examples/sec: 162.243
# INFO:tensorflow:global_step/sec: 1.23136
# INFO:tensorflow:examples/sec: 157.614
# INFO:tensorflow:global_step/sec: 1.21086
# INFO:tensorflow:examples/sec: 154.991
# INFO:tensorflow:global_step/sec: 1.26219
# INFO:tensorflow:examples/sec: 161.561
# INFO:tensorflow:global_step/sec: 1.20814
# INFO:tensorflow:examples/sec: 154.641
# INFO:tensorflow:global_step/sec: 1.22162
# INFO:tensorflow:examples/sec: 156.368
# INFO:tensorflow:Saving checkpoints for 3000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-11:38:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-11:39:18
# INFO:tensorflow:Saving dict for global step 3000: eval_accuracy = 0.879766, eval_loss = 0.0204479, global_step = 3000, loss = 0.0204479
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-3000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.792468
# INFO:tensorflow:examples/sec: 101.436
# INFO:tensorflow:global_step/sec: 1.26369
# INFO:tensorflow:examples/sec: 161.752
# INFO:tensorflow:global_step/sec: 1.24051
# INFO:tensorflow:examples/sec: 158.786
# INFO:tensorflow:global_step/sec: 1.19673
# INFO:tensorflow:examples/sec: 153.181
# INFO:tensorflow:global_step/sec: 1.26791
# INFO:tensorflow:examples/sec: 162.292
# INFO:tensorflow:global_step/sec: 1.22221
# INFO:tensorflow:examples/sec: 156.443
# INFO:tensorflow:global_step/sec: 1.2142
# INFO:tensorflow:examples/sec: 155.418
# INFO:tensorflow:global_step/sec: 1.26909
# INFO:tensorflow:examples/sec: 162.444
# INFO:tensorflow:global_step/sec: 1.20631
# INFO:tensorflow:examples/sec: 154.407
# INFO:tensorflow:global_step/sec: 1.23275
# INFO:tensorflow:examples/sec: 157.792
# INFO:tensorflow:Saving checkpoints for 4000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-11:53:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-11:53:34
# INFO:tensorflow:Saving dict for global step 4000: eval_accuracy = 0.875547, eval_loss = 0.0208642, global_step = 4000, loss = 0.0208642
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-4000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.785034
# INFO:tensorflow:examples/sec: 100.484
# INFO:tensorflow:global_step/sec: 1.25869
# INFO:tensorflow:examples/sec: 161.113
# INFO:tensorflow:global_step/sec: 1.23817
# INFO:tensorflow:examples/sec: 158.486
# INFO:tensorflow:global_step/sec: 1.19195
# INFO:tensorflow:examples/sec: 152.57
# INFO:tensorflow:global_step/sec: 1.25578
# INFO:tensorflow:examples/sec: 160.739
# INFO:tensorflow:global_step/sec: 1.22514
# INFO:tensorflow:examples/sec: 156.818
# INFO:tensorflow:global_step/sec: 1.2069
# INFO:tensorflow:examples/sec: 154.483
# INFO:tensorflow:global_step/sec: 1.26349
# INFO:tensorflow:examples/sec: 161.727
# INFO:tensorflow:global_step/sec: 1.21065
# INFO:tensorflow:examples/sec: 154.963
# INFO:tensorflow:global_step/sec: 1.22418
# INFO:tensorflow:examples/sec: 156.695
# INFO:tensorflow:Saving checkpoints for 5000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-12:07:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-12:07:53
# INFO:tensorflow:Saving dict for global step 5000: eval_accuracy = 0.888281, eval_loss = 0.020526, global_step = 5000, loss = 0.020526
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-5000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.789503
# INFO:tensorflow:examples/sec: 101.056
# INFO:tensorflow:global_step/sec: 1.26167
# INFO:tensorflow:examples/sec: 161.494
# INFO:tensorflow:global_step/sec: 1.23666
# INFO:tensorflow:examples/sec: 158.293
# INFO:tensorflow:global_step/sec: 1.19473
# INFO:tensorflow:examples/sec: 152.925
# INFO:tensorflow:global_step/sec: 1.26179
# INFO:tensorflow:examples/sec: 161.509
# INFO:tensorflow:global_step/sec: 1.21899
# INFO:tensorflow:examples/sec: 156.031
# INFO:tensorflow:global_step/sec: 1.21009
# INFO:tensorflow:examples/sec: 154.891
# INFO:tensorflow:global_step/sec: 1.25984
# INFO:tensorflow:examples/sec: 161.259
# INFO:tensorflow:global_step/sec: 1.20772
# INFO:tensorflow:examples/sec: 154.588
# INFO:tensorflow:global_step/sec: 1.22809
# INFO:tensorflow:examples/sec: 157.196
# INFO:tensorflow:Saving checkpoints for 6000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-12:21:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-12:22:10
# INFO:tensorflow:Saving dict for global step 6000: eval_accuracy = 0.895703, eval_loss = 0.0217895, global_step = 6000, loss = 0.0217895
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-6000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.790651
# INFO:tensorflow:examples/sec: 101.203
# INFO:tensorflow:global_step/sec: 1.26571
# INFO:tensorflow:examples/sec: 162.011
# INFO:tensorflow:global_step/sec: 1.23673
# INFO:tensorflow:examples/sec: 158.301
# INFO:tensorflow:global_step/sec: 1.19955
# INFO:tensorflow:examples/sec: 153.543
# INFO:tensorflow:global_step/sec: 1.26815
# INFO:tensorflow:examples/sec: 162.323
# INFO:tensorflow:global_step/sec: 1.21815
# INFO:tensorflow:examples/sec: 155.923
# INFO:tensorflow:global_step/sec: 1.2172
# INFO:tensorflow:examples/sec: 155.802
# INFO:tensorflow:global_step/sec: 1.2682
# INFO:tensorflow:examples/sec: 162.33
# INFO:tensorflow:global_step/sec: 1.2052
# INFO:tensorflow:examples/sec: 154.266
# INFO:tensorflow:global_step/sec: 1.23366
# INFO:tensorflow:examples/sec: 157.908
# INFO:tensorflow:Saving checkpoints for 7000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-12:35:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-12:36:28
# INFO:tensorflow:Saving dict for global step 7000: eval_accuracy = 0.891328, eval_loss = 0.0222775, global_step = 7000, loss = 0.0222775
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-7000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.781871
# INFO:tensorflow:examples/sec: 100.08
# INFO:tensorflow:global_step/sec: 1.52545
# INFO:tensorflow:examples/sec: 195.258
# INFO:tensorflow:global_step/sec: 1.41334
# INFO:tensorflow:examples/sec: 180.907
# INFO:tensorflow:global_step/sec: 1.21887
# INFO:tensorflow:examples/sec: 156.015
# INFO:tensorflow:global_step/sec: 1.18995
# INFO:tensorflow:examples/sec: 152.314
# INFO:tensorflow:global_step/sec: 1.22091
# INFO:tensorflow:examples/sec: 156.276
# INFO:tensorflow:global_step/sec: 1.22139
# INFO:tensorflow:examples/sec: 156.338
# INFO:tensorflow:global_step/sec: 1.22207
# INFO:tensorflow:examples/sec: 156.425
# INFO:tensorflow:global_step/sec: 1.19806
# INFO:tensorflow:examples/sec: 153.352
# INFO:tensorflow:global_step/sec: 1.20467
# INFO:tensorflow:examples/sec: 154.198
# INFO:tensorflow:Saving checkpoints for 8000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-12:50:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-12:50:30
# INFO:tensorflow:Saving dict for global step 8000: eval_accuracy = 0.895391, eval_loss = 0.0229237, global_step = 8000, loss = 0.0229237
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-8000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.778612
# INFO:tensorflow:examples/sec: 99.6623
# INFO:tensorflow:global_step/sec: 1.20475
# INFO:tensorflow:examples/sec: 154.207
# INFO:tensorflow:global_step/sec: 1.18607
# INFO:tensorflow:examples/sec: 151.817
# INFO:tensorflow:global_step/sec: 1.21519
# INFO:tensorflow:examples/sec: 155.545
# INFO:tensorflow:global_step/sec: 1.2186
# INFO:tensorflow:examples/sec: 155.981
# INFO:tensorflow:global_step/sec: 1.22478
# INFO:tensorflow:examples/sec: 156.772
# INFO:tensorflow:global_step/sec: 1.19926
# INFO:tensorflow:examples/sec: 153.506
# INFO:tensorflow:global_step/sec: 1.20471
# INFO:tensorflow:examples/sec: 154.202
# INFO:tensorflow:global_step/sec: 1.21863
# INFO:tensorflow:examples/sec: 155.985
# INFO:tensorflow:global_step/sec: 1.21797
# INFO:tensorflow:examples/sec: 155.9
# INFO:tensorflow:Saving checkpoints for 9000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-13:04:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-13:05:05
# INFO:tensorflow:Saving dict for global step 9000: eval_accuracy = 0.894687, eval_loss = 0.0239378, global_step = 9000, loss = 0.0239378
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-9000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.763559
# INFO:tensorflow:examples/sec: 97.7356
# INFO:tensorflow:global_step/sec: 1.21368
# INFO:tensorflow:examples/sec: 155.351
# INFO:tensorflow:global_step/sec: 1.21593
# INFO:tensorflow:examples/sec: 155.639
# INFO:tensorflow:global_step/sec: 1.21772
# INFO:tensorflow:examples/sec: 155.868
# INFO:tensorflow:global_step/sec: 1.19535
# INFO:tensorflow:examples/sec: 153.004
# INFO:tensorflow:global_step/sec: 1.19506
# INFO:tensorflow:examples/sec: 152.968
# INFO:tensorflow:global_step/sec: 1.22176
# INFO:tensorflow:examples/sec: 156.386
# INFO:tensorflow:global_step/sec: 1.21893
# INFO:tensorflow:examples/sec: 156.024
# INFO:tensorflow:global_step/sec: 1.21852
# INFO:tensorflow:examples/sec: 155.971
# INFO:tensorflow:global_step/sec: 1.18596
# INFO:tensorflow:examples/sec: 151.802
# INFO:tensorflow:Saving checkpoints for 10000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-13:19:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-13:19:40
# INFO:tensorflow:Saving dict for global step 10000: eval_accuracy = 0.897031, eval_loss = 0.0250611, global_step = 10000, loss = 0.0250611
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-10000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.769784
# INFO:tensorflow:examples/sec: 98.5323
# INFO:tensorflow:global_step/sec: 1.22327
# INFO:tensorflow:examples/sec: 156.578
# INFO:tensorflow:global_step/sec: 1.19899
# INFO:tensorflow:examples/sec: 153.471
# INFO:tensorflow:global_step/sec: 1.1939
# INFO:tensorflow:examples/sec: 152.819
# INFO:tensorflow:global_step/sec: 1.21359
# INFO:tensorflow:examples/sec: 155.339
# INFO:tensorflow:global_step/sec: 1.21754
# INFO:tensorflow:examples/sec: 155.845
# INFO:tensorflow:global_step/sec: 1.22261
# INFO:tensorflow:examples/sec: 156.495
# INFO:tensorflow:global_step/sec: 1.18835
# INFO:tensorflow:examples/sec: 152.108
# INFO:tensorflow:global_step/sec: 1.20154
# INFO:tensorflow:examples/sec: 153.797
# INFO:tensorflow:global_step/sec: 1.22196
# INFO:tensorflow:examples/sec: 156.411
# INFO:tensorflow:Saving checkpoints for 11000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-13:33:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-11000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-13:34:13
# INFO:tensorflow:Saving dict for global step 11000: eval_accuracy = 0.894141, eval_loss = 0.0269108, global_step = 11000, loss = 0.0269108
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-11000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.773827
# INFO:tensorflow:examples/sec: 99.0499
# INFO:tensorflow:global_step/sec: 1.19204
# INFO:tensorflow:examples/sec: 152.582
# INFO:tensorflow:global_step/sec: 1.21573
# INFO:tensorflow:examples/sec: 155.613
# INFO:tensorflow:global_step/sec: 1.21852
# INFO:tensorflow:examples/sec: 155.97
# INFO:tensorflow:global_step/sec: 1.21783
# INFO:tensorflow:examples/sec: 155.882
# INFO:tensorflow:global_step/sec: 1.19624
# INFO:tensorflow:examples/sec: 153.118
# INFO:tensorflow:global_step/sec: 1.19815
# INFO:tensorflow:examples/sec: 153.363
# INFO:tensorflow:global_step/sec: 1.21841
# INFO:tensorflow:examples/sec: 155.957
# INFO:tensorflow:global_step/sec: 1.21674
# INFO:tensorflow:examples/sec: 155.742
# INFO:tensorflow:global_step/sec: 1.21546
# INFO:tensorflow:examples/sec: 155.578
# INFO:tensorflow:Saving checkpoints for 12000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-13:47:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-12000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-13:48:24
# INFO:tensorflow:Saving dict for global step 12000: eval_accuracy = 0.897187, eval_loss = 0.027137, global_step = 12000, loss = 0.027137
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-12000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.936988
# INFO:tensorflow:examples/sec: 119.934
# INFO:tensorflow:global_step/sec: 1.23829
# INFO:tensorflow:examples/sec: 158.501
# INFO:tensorflow:global_step/sec: 1.22983
# INFO:tensorflow:examples/sec: 157.418
# INFO:tensorflow:global_step/sec: 1.2058
# INFO:tensorflow:examples/sec: 154.343
# INFO:tensorflow:global_step/sec: 1.21235
# INFO:tensorflow:examples/sec: 155.18
# INFO:tensorflow:global_step/sec: 1.22854
# INFO:tensorflow:examples/sec: 157.253
# INFO:tensorflow:global_step/sec: 1.22684
# INFO:tensorflow:examples/sec: 157.036
# INFO:tensorflow:global_step/sec: 1.22111
# INFO:tensorflow:examples/sec: 156.302
# INFO:tensorflow:global_step/sec: 1.19259
# INFO:tensorflow:examples/sec: 152.651
# INFO:tensorflow:global_step/sec: 1.22759
# INFO:tensorflow:examples/sec: 157.131
# INFO:tensorflow:Saving checkpoints for 13000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-14:02:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-14:02:48
# INFO:tensorflow:Saving dict for global step 13000: eval_accuracy = 0.896875, eval_loss = 0.0277305, global_step = 13000, loss = 0.0277305
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-13000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.793659
# INFO:tensorflow:examples/sec: 101.588
# INFO:tensorflow:global_step/sec: 1.19377
# INFO:tensorflow:examples/sec: 152.803
# INFO:tensorflow:global_step/sec: 1.23183
# INFO:tensorflow:examples/sec: 157.674
# INFO:tensorflow:global_step/sec: 1.22829
# INFO:tensorflow:examples/sec: 157.221
# INFO:tensorflow:global_step/sec: 1.22903
# INFO:tensorflow:examples/sec: 157.316
# INFO:tensorflow:global_step/sec: 1.197
# INFO:tensorflow:examples/sec: 153.216
# INFO:tensorflow:global_step/sec: 1.21199
# INFO:tensorflow:examples/sec: 155.135
# INFO:tensorflow:global_step/sec: 1.22576
# INFO:tensorflow:examples/sec: 156.897
# INFO:tensorflow:global_step/sec: 1.22638
# INFO:tensorflow:examples/sec: 156.976
# INFO:tensorflow:global_step/sec: 1.2156
# INFO:tensorflow:examples/sec: 155.597
# INFO:tensorflow:Saving checkpoints for 14000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-14:16:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-14:17:19
# INFO:tensorflow:Saving dict for global step 14000: eval_accuracy = 0.896016, eval_loss = 0.0289977, global_step = 14000, loss = 0.0289977
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-14000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.754241
# INFO:tensorflow:examples/sec: 96.5429
# INFO:tensorflow:global_step/sec: 1.22614
# INFO:tensorflow:examples/sec: 156.946
# INFO:tensorflow:global_step/sec: 1.22914
# INFO:tensorflow:examples/sec: 157.33
# INFO:tensorflow:global_step/sec: 1.19339
# INFO:tensorflow:examples/sec: 152.755
# INFO:tensorflow:global_step/sec: 1.21641
# INFO:tensorflow:examples/sec: 155.701
# INFO:tensorflow:global_step/sec: 1.2262
# INFO:tensorflow:examples/sec: 156.953
# INFO:tensorflow:global_step/sec: 1.2279
# INFO:tensorflow:examples/sec: 157.171
# INFO:tensorflow:global_step/sec: 1.21062
# INFO:tensorflow:examples/sec: 154.959
# INFO:tensorflow:global_step/sec: 1.19885
# INFO:tensorflow:examples/sec: 153.453
# INFO:tensorflow:global_step/sec: 1.22583
# INFO:tensorflow:examples/sec: 156.906
# INFO:tensorflow:Saving checkpoints for 15000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-14:31:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-14:31:45
# INFO:tensorflow:Saving dict for global step 15000: eval_accuracy = 0.893828, eval_loss = 0.0295557, global_step = 15000, loss = 0.0295557
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-15000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.791984
# INFO:tensorflow:examples/sec: 101.374
# INFO:tensorflow:global_step/sec: 1.20034
# INFO:tensorflow:examples/sec: 153.644
# INFO:tensorflow:global_step/sec: 1.22822
# INFO:tensorflow:examples/sec: 157.212
# INFO:tensorflow:global_step/sec: 1.22729
# INFO:tensorflow:examples/sec: 157.093
# INFO:tensorflow:global_step/sec: 1.22783
# INFO:tensorflow:examples/sec: 157.162
# INFO:tensorflow:global_step/sec: 1.19317
# INFO:tensorflow:examples/sec: 152.725
# INFO:tensorflow:global_step/sec: 1.21415
# INFO:tensorflow:examples/sec: 155.411
# INFO:tensorflow:global_step/sec: 1.2248
# INFO:tensorflow:examples/sec: 156.774
# INFO:tensorflow:global_step/sec: 1.22749
# INFO:tensorflow:examples/sec: 157.119
# INFO:tensorflow:global_step/sec: 1.21508
# INFO:tensorflow:examples/sec: 155.53
# INFO:tensorflow:Saving checkpoints for 16000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-14:45:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-14:46:16
# INFO:tensorflow:Saving dict for global step 16000: eval_accuracy = 0.896719, eval_loss = 0.0306264, global_step = 16000, loss = 0.0306264
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-16000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.757492
# INFO:tensorflow:examples/sec: 96.959
# INFO:tensorflow:global_step/sec: 1.23028
# INFO:tensorflow:examples/sec: 157.476
# INFO:tensorflow:global_step/sec: 1.22647
# INFO:tensorflow:examples/sec: 156.988
# INFO:tensorflow:global_step/sec: 1.19338
# INFO:tensorflow:examples/sec: 152.752
# INFO:tensorflow:global_step/sec: 1.225
# INFO:tensorflow:examples/sec: 156.8
# INFO:tensorflow:global_step/sec: 1.22462
# INFO:tensorflow:examples/sec: 156.751
# INFO:tensorflow:global_step/sec: 1.22781
# INFO:tensorflow:examples/sec: 157.16
# INFO:tensorflow:global_step/sec: 1.20321
# INFO:tensorflow:examples/sec: 154.011
# INFO:tensorflow:global_step/sec: 1.70026
# INFO:tensorflow:examples/sec: 217.633
# INFO:tensorflow:global_step/sec: 1.20386
# INFO:tensorflow:examples/sec: 154.094
# INFO:tensorflow:Saving checkpoints for 17000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-14:59:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-17000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-15:00:18
# INFO:tensorflow:Saving dict for global step 17000: eval_accuracy = 0.896328, eval_loss = 0.0310431, global_step = 17000, loss = 0.0310431
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-17000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.799149
# INFO:tensorflow:examples/sec: 102.291
# INFO:tensorflow:global_step/sec: 1.23762
# INFO:tensorflow:examples/sec: 158.415
# INFO:tensorflow:global_step/sec: 1.25492
# INFO:tensorflow:examples/sec: 160.629
# INFO:tensorflow:global_step/sec: 1.18365
# INFO:tensorflow:examples/sec: 151.507
# INFO:tensorflow:global_step/sec: 1.25282
# INFO:tensorflow:examples/sec: 160.361
# INFO:tensorflow:global_step/sec: 1.24163
# INFO:tensorflow:examples/sec: 158.929
# INFO:tensorflow:global_step/sec: 1.19116
# INFO:tensorflow:examples/sec: 152.469
# INFO:tensorflow:global_step/sec: 1.25401
# INFO:tensorflow:examples/sec: 160.513
# INFO:tensorflow:global_step/sec: 1.23187
# INFO:tensorflow:examples/sec: 157.679
# INFO:tensorflow:global_step/sec: 1.19621
# INFO:tensorflow:examples/sec: 153.115
# INFO:tensorflow:Saving checkpoints for 18000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-15:14:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-15:14:38
# INFO:tensorflow:Saving dict for global step 18000: eval_accuracy = 0.897734, eval_loss = 0.0316973, global_step = 18000, loss = 0.0316973
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-18000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.792468
# INFO:tensorflow:examples/sec: 101.436
# INFO:tensorflow:global_step/sec: 1.22291
# INFO:tensorflow:examples/sec: 156.533
# INFO:tensorflow:global_step/sec: 1.25881
# INFO:tensorflow:examples/sec: 161.128
# INFO:tensorflow:global_step/sec: 1.19048
# INFO:tensorflow:examples/sec: 152.382
# INFO:tensorflow:global_step/sec: 1.23714
# INFO:tensorflow:examples/sec: 158.353
# INFO:tensorflow:global_step/sec: 1.25616
# INFO:tensorflow:examples/sec: 160.789
# INFO:tensorflow:global_step/sec: 1.18042
# INFO:tensorflow:examples/sec: 151.094
# INFO:tensorflow:global_step/sec: 1.25031
# INFO:tensorflow:examples/sec: 160.04
# INFO:tensorflow:global_step/sec: 1.2398
# INFO:tensorflow:examples/sec: 158.695
# INFO:tensorflow:global_step/sec: 1.18857
# INFO:tensorflow:examples/sec: 152.137
# INFO:tensorflow:Saving checkpoints for 19000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-15:28:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-19000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-15:28:58
# INFO:tensorflow:Saving dict for global step 19000: eval_accuracy = 0.897422, eval_loss = 0.0321307, global_step = 19000, loss = 0.0321307
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-19000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.801244
# INFO:tensorflow:examples/sec: 102.559
# INFO:tensorflow:global_step/sec: 1.21681
# INFO:tensorflow:examples/sec: 155.752
# INFO:tensorflow:global_step/sec: 1.25766
# INFO:tensorflow:examples/sec: 160.981
# INFO:tensorflow:global_step/sec: 1.19644
# INFO:tensorflow:examples/sec: 153.144
# INFO:tensorflow:global_step/sec: 1.22676
# INFO:tensorflow:examples/sec: 157.025
# INFO:tensorflow:global_step/sec: 1.25705
# INFO:tensorflow:examples/sec: 160.903
# INFO:tensorflow:global_step/sec: 1.18568
# INFO:tensorflow:examples/sec: 151.767
# INFO:tensorflow:global_step/sec: 1.24439
# INFO:tensorflow:examples/sec: 159.282
# INFO:tensorflow:global_step/sec: 1.24707
# INFO:tensorflow:examples/sec: 159.625
# INFO:tensorflow:global_step/sec: 1.18288
# INFO:tensorflow:examples/sec: 151.409
# INFO:tensorflow:Saving checkpoints for 20000 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-15:42:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-15:43:18
# INFO:tensorflow:Saving dict for global step 20000: eval_accuracy = 0.898672, eval_loss = 0.0322227, global_step = 20000, loss = 0.0322227
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-20000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:global_step/sec: 0.802694
# INFO:tensorflow:examples/sec: 102.745
# INFO:tensorflow:Saving checkpoints for 20034 into /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (600 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-10-15:44:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-20034
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-12-10-15:44:32
# INFO:tensorflow:Saving dict for global step 20034: eval_accuracy = 0.898594, eval_loss = 0.0322248, global_step = 20034, loss = 0.0322248
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20034: /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-20034
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Loss for final step: 0.00263214.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Writing example 0 of 80126
# INFO:tensorflow:Writing example 10000 of 80126
# INFO:tensorflow:Writing example 20000 of 80126
# INFO:tensorflow:Writing example 30000 of 80126
# INFO:tensorflow:Writing example 40000 of 80126
# INFO:tensorflow:Writing example 50000 of 80126
# INFO:tensorflow:Writing example 60000 of 80126
# INFO:tensorflow:Writing example 70000 of 80126
# INFO:tensorflow:Writing example 80000 of 80126
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:*** Features ***
# INFO:tensorflow:  name = input_ids, shape = (?, 43)
# INFO:tensorflow:  name = input_mask, shape = (?, 43)
# INFO:tensorflow:  name = label_ids, shape = (?,)
# INFO:tensorflow:  name = segment_ids, shape = (?, 43)
# INFO:tensorflow:**** Trainable Variables ****
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /home/dmlab/sundong/competition/wsdm2019/fakenews/notebook/results_optimized2_chinese_L-12_H-768_A-12/model.ckpt-20034
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished

# %%
## Geomean

submission_ensemble_path = '../data/sample_submission_sd_BERT_weightedavg_4model_cn.csv'
smax = {}
BERT_MODEL_LIST = ['chinese_L-12_H-768_A-12', 'chinese_L-12_H-768_A-12_EN', 'multi_cased_L-12_H-768_A-12', 'uncased_L-24_H-1024_A-16']
# BERT_MODEL_LIST = ['chinese_L-12_H-768_A-12']
for BERT_MODEL in BERT_MODEL_LIST: 
    pkls_path = '../data/sample_submission_sd_BERT_'+BERT_MODEL+'_RESULT_SOFTMAX.p'
    with open(pkls_path, 'rb') as file:
        smax[BERT_MODEL] = np.asarray(pickle.load(file))
        
# ens_rslt = np.multiply(smax['chinese_L-12_H-768_A-12', smax['multi_cased_L-12_H-768_A-12'], smax['uncased_L-24_H-1024_A-16']])   
ens_rslt = np.average(np.array([smax['chinese_L-12_H-768_A-12'], smax['multi_cased_L-12_H-768_A-12'], smax['uncased_L-24_H-1024_A-16'], smax['chinese_L-12_H-768_A-12_EN']]), 
                      axis=0, weights=[0.6,0.1,0.1,0.2])


df_test = pd.read_csv(test_path)
df_test['pred_label'] = np.argmax(ens_rslt, axis=1)
idx_label = {0:'unrelated', 1:'agreed', 2:'disagreed'}
df_test['pred_label'] = df_test['pred_label'].apply(lambda x: idx_label[x])

df_test[['id', 'pred_label']].rename(columns={'id':'Id','pred_label':'Category'}).to_csv(submission_ensemble_path, index=False)

# %%
ens_rslt = np.average(np.array([smax['chinese_L-12_H-768_A-12'], smax['multi_cased_L-12_H-768_A-12'], smax['uncased_L-24_H-1024_A-16'], smax['chinese_L-12_H-768_A-12_EN']]), 
                      axis=0, weights=[0.6,0.1,0.1,0.2])

# %%
ens_rslt

# %%
df_test['pred_label'].value_counts()

# %%
df_train = pd.read_csv('../data/train.csv')
dft_tr = df_train['label'].value_counts()
dft_tr/np.sum(dft_tr)

# %%
dft = df_test['pred_label'].value_counts()
dft/np.sum(dft)
