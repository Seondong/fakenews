# %%
import warnings
warnings.filterwarnings('ignore')

import random
import numpy as np
import mxnet as mx
from mxnet import gluon
import gluonnlp as nlp

# %%
np.random.seed(100)
random.seed(100)
mx.random.seed(10000)
ctx = mx.gpu(0)

# %%
from bert import *

bert_base, vocabulary = nlp.model.get_model('bert_12_768_12',
                                             dataset_name='wiki_multilingual',
                                             pretrained=True, ctx=ctx, use_pooler=True,
                                             use_decoder=False, use_classifier=False)
print(bert_base)
# Out:
# Vocab file is not found. Downloading.
# Downloading /home/dmlab/sundong/.mxnet/models/wiki_multilingual-4cf30ef8.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/dataset/vocab/wiki_multilingual-4cf30ef8.zip...
# Downloading /home/dmlab/sundong/.mxnet/models/bert_12_768_12_wiki_multilingual-237f3985.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/bert_12_768_12_wiki_multilingual-237f3985.zip...
# BERTModel(
#   (encoder): BERTEncoder(
#     (dropout_layer): Dropout(p = 0.1, axes=())
#     (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#     (transformer_cells): HybridSequential(
#       (0): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (1): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (2): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (3): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (4): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (5): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (6): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (7): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (8): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (9): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (10): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#       (11): BERTEncoderCell(
#         (dropout_layer): Dropout(p = 0.1, axes=())
#         (attention_cell): MultiHeadAttentionCell(
#           (_base_cell): DotProductAttentionCell(
#             (_dropout_layer): Dropout(p = 0.1, axes=())
#           )
#           (proj_query): Dense(768 -> 768, linear)
#           (proj_key): Dense(768 -> 768, linear)
#           (proj_value): Dense(768 -> 768, linear)
#         )
#         (proj): Dense(768 -> 768, linear)
#         (ffn): BERTPositionwiseFFN(
#           (ffn_1): Dense(768 -> 3072, linear)
#           (activation): GELU()
#           (ffn_2): Dense(3072 -> 768, linear)
#           (dropout_layer): Dropout(p = 0.1, axes=())
#           (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#         )
#         (layer_norm): BERTLayerNorm(in_channels=768, epsilon=1e-12)
#       )
#     )
#   )
#   (word_embed): HybridSequential(
#     (0): Embedding(105879 -> 768, float32)
#     (1): Dropout(p = 0.1, axes=())
#   )
#   (token_type_embed): HybridSequential(
#     (0): Embedding(2 -> 768, float32)
#     (1): Dropout(p = 0.1, axes=())
#   )
#   (pooler): Dense(768 -> 768, Activation(tanh))
# )

# %%
model = bert.BERTClassifier(bert_base, num_classes=2, dropout=0.1)
# only need to initialize the classifier layer.
model.classifier.initialize(init=mx.init.Normal(0.02), ctx=ctx)
model.hybridize(static_alloc=True)

# softmax cross entropy loss for classification
loss_function = gluon.loss.SoftmaxCELoss()
loss_function.hybridize(static_alloc=True)

metric = mx.metric.Accuracy()

# %%
data_train.get_labels
# Out:
# <function bert.dataset.MRPCDataset.get_labels>

# %%
data_train = dataset.FakeNewsDataset('dev', root='./glue_data/Fake')
sample_id = 0
# sentence a
print(data_train[sample_id][0])
# sentence b
print(data_train[sample_id][1])
# 1 means equivalent, 0 means not equivalent
print(data_train[sample_id][2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-876b23dc21a2> in <module>()
# ----> 1 data_train = dataset.MRPCDataset('dev', root='./glue_data/Fake')
#       2 sample_id = 0
#       3 # sentence a
#       4 print(data_train[sample_id][0])
#       5 # sentence b
#
# ~/competition/wsdm2019/fakenews/notebook/bert/dataset.py in __init__(self, segment, root)
#      46         A_IDX, B_IDX, LABEL_IDX = 3, 4, 0
#      47         fields = [A_IDX, B_IDX, LABEL_IDX]
# ---> 48         super(MRPCDataset, self).__init__(path, num_discard_samples=1, field_indices=fields)
#      49
#      50     @staticmethod
#
# /home/dmlab/ksedm1/anaconda3/envs/py36/lib/python3.6/site-packages/gluonnlp/data/dataset.py in __init__(self, filename, encoding, sample_splitter, field_separator, num_discard_samples, field_indices)
#     129         self._num_discard_samples = num_discard_samples
#     130         self._field_indices = field_indices
# --> 131         super(TSVDataset, self).__init__(self._read())
#     132
#     133     def _should_discard(self):
#
# /home/dmlab/ksedm1/anaconda3/envs/py36/lib/python3.6/site-packages/gluonnlp/data/dataset.py in _read(self)
#     148             samples = (s for s in self._sample_splitter(content) if not self._should_discard())
#     149             if self._field_separator:
# --> 150                 samples = [self._field_selector(self._field_separator(s)) for s in samples]
#     151             all_samples += samples
#     152         return all_samples
#
# /home/dmlab/ksedm1/anaconda3/envs/py36/lib/python3.6/site-packages/gluonnlp/data/dataset.py in <listcomp>(.0)
#     148             samples = (s for s in self._sample_splitter(content) if not self._should_discard())
#     149             if self._field_separator:
# --> 150                 samples = [self._field_selector(self._field_separator(s)) for s in samples]
#     151             all_samples += samples
#     152         return all_samples
#
# /home/dmlab/ksedm1/anaconda3/envs/py36/lib/python3.6/site-packages/gluonnlp/data/dataset.py in _field_selector(self, fields)
#     139         if not self._field_indices:
#     140             return fields
# --> 141         return [fields[i] for i in self._field_indices]
#     142
#     143     def _read(self):
#
# /home/dmlab/ksedm1/anaconda3/envs/py36/lib/python3.6/site-packages/gluonnlp/data/dataset.py in <listcomp>(.0)
#     139         if not self._field_indices:
#     140             return fields
# --> 141         return [fields[i] for i in self._field_indices]
#     142
#     143     def _read(self):
#
# IndexError: list index out of range

# %%
data_train
